# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %%
# Path to your GeoPackage file
geopackage_path = "data/London_Points_Of_Interest.gpkg"

# Read the GeoPackage into a GeoDataFrame
gdf = gpd.read_file(geopackage_path)

# Define the list of desired classnames
desired_classes = ["Pubs, Bars and Inns", "Cafes, Snack Bars and Tea Rooms", "Restaurants"]

# Filter the GeoDataFrame
filtered_gdf = gdf[gdf['classname'].isin(desired_classes)]

# Display the result
print(filtered_gdf)
# Out:
#             id     ref_no                            name pointx_class  \
# 6682      8137   19521780        Heston West Service Area     01020043
# 6685      8142   19521779        Heston East Service Area     01020043
# 6703      8167   18857214  Welcome Break (London Gateway)     01020043
# 51122    62532   78527081                Hollydale Tavern     01020034
# 65496    79353  157767852             The Diner in London     01020043
# ...        ...        ...                             ...          ...
# 324257  390991  118149604                          Sami's     01020034
# 324258  390992  118149728                           Roxie     01020034
# 324259  390993  124036871        Strongroom Bar & Kitchen     01020034
# 324260  390994  118152258                      The Graces     01020034
# 324261  390995  124756747                      The Garden     01020034
#
#                                  groupname         categoryname  \
# 6682    Accommodation, Eating and Drinking  Eating and Drinking
# 6685    Accommodation, Eating and Drinking  Eating and Drinking
# 6703    Accommodation, Eating and Drinking  Eating and Drinking
# 51122   Accommodation, Eating and Drinking  Eating and Drinking
# 65496   Accommodation, Eating and Drinking  Eating and Drinking
# ...                                    ...                  ...
# 324257  Accommodation, Eating and Drinking  Eating and Drinking
# 324258  Accommodation, Eating and Drinking  Eating and Drinking
# 324259  Accommodation, Eating and Drinking  Eating and Drinking
# 324260  Accommodation, Eating and Drinking  Eating and Drinking
# 324261  Accommodation, Eating and Drinking  Eating and Drinking
#
#                   classname  feature_easting  feature_northing  pos_accuracy  \
# 6682            Restaurants         511446.0          177847.0             1
# 6685            Restaurants         512027.0          177854.0             1
# 6703            Restaurants         520246.0          193914.0             1
# 51122   Pubs, Bars and Inns         535106.0          176307.0             1
# 65496           Restaurants         526051.5          166504.3             1
# ...                     ...              ...               ...           ...
# 324257  Pubs, Bars and Inns         519519.8          192184.3             1
# 324258  Pubs, Bars and Inns         524272.0          174966.0             1
# 324259  Pubs, Bars and Inns         533286.4          182526.5             1
# 324260  Pubs, Bars and Inns         535321.0          169005.0             1
# 324261  Pubs, Bars and Inns         531887.0          171904.0             1
#
#         ...  postcode             admin_boundary  telephone_number  \
# 6682    ...   TW5 9NA    Hounslow London Borough              None
# 6685    ...   TW5 9NA    Hounslow London Borough              None
# 6703    ...   NW7 3HU      Barnet London Borough              None
# 51122   ...  SE15 2TF   Southwark London Borough              None
# 65496   ...   SM1 3HE      Sutton London Borough       02082966028
# ...     ...       ...                        ...               ...
# 324257  ...   HA8 7AX      Barnet London Borough              None
# 324258  ...  SW15 2SP  Wandsworth London Borough              None
# 324259  ...  EC2A 3PJ     Hackney London Borough              None
# 324260  ...  SE20 7YA     Bromley London Borough              None
# 324261  ...  SE27 0HS     Lambeth London Borough              None
#
#                            url                     brand   qualifier_type  \
# 6682          www.moto-way.com  Moto Hospitality Limited  Restaurant Type
# 6685          www.moto-way.com  Moto Hospitality Limited  Restaurant Type
# 6703    www.welcomebreak.co.uk             Welcome Break  Restaurant Type
# 51122                     None                      None             None
# 65496                     None                      None  Restaurant Type
# ...                        ...                       ...              ...
# 324257                    None                      None             None
# 324258                    None                      None             None
# 324259                    None                      None             None
# 324260                    None                      None             None
# 324261                    None                      None             None
#
#            qualifier_data               provenance supply_date  \
# 6682             Roadside                     Moto  2024-09-01
# 6685             Roadside                     Moto  2024-09-01
# 6703             Roadside  Welcome Break Group Ltd  2024-09-01
# 51122                None                   PointX  2024-09-01
# 65496   Motorway Services          118 Information  2024-09-01
# ...                   ...                      ...         ...
# 324257               None       Local Data Company  2024-09-01
# 324258               None       Local Data Company  2024-09-01
# 324259               None       Local Data Company  2024-09-01
# 324260               None       Local Data Company  2024-09-01
# 324261               None       Local Data Company  2024-09-01
#
#                          geometry
# 6682        POINT (511446 177847)
# 6685        POINT (512027 177854)
# 6703        POINT (520246 193914)
# 51122       POINT (535106 176307)
# 65496   POINT (526051.5 166504.3)
# ...                           ...
# 324257  POINT (519519.8 192184.3)
# 324258      POINT (524272 174966)
# 324259  POINT (533286.4 182526.5)
# 324260      POINT (535321 169005)
# 324261      POINT (531887 171904)
#
# [24211 rows x 30 columns]
